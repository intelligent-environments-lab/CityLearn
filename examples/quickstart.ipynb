# %% [markdown]
# <a href="https://colab.research.google.com/github/intelligent-environments-lab/CityLearn/blob/master/examples/quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QuickStart
#
# Install the latest CityLearn version from PyPi with the :code:`pip` command:

# %%
# !pip install CityLearn

# %% [markdown]
# ## Centralized RBC
# Run the following to simulate an environment controlled by centralized RBC agent for a single episode:

# %%
from citylearn.agents.rbc import BasicRBC as RBCAgent
from citylearn.citylearn import CityLearnEnv

dataset_name = 'citylearn_challenge_2022_phase_1'
env = CityLearnEnv(dataset_name, central_agent=True, simulation_end_time_step=1000)
model = RBCAgent(env)
model.learn(episodes=1)

# print cost functions at the end of episode
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value')
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /usr/local/lib/python3.10/dist-packages/citylearn/citylearn.py:31: DeprecationWarning: private variables, such as '_EvaluationCondition__DEFAULT', will be normal attributes in 3.11
#   __DEFAULT = ''
# /usr/local/lib/python3.10/dist-packages/citylearn/citylearn.py:32: DeprecationWarning: private variables, such as '_EvaluationCondition__STORAGE_SUFFIX', will be normal attributes in 3.11
#   __STORAGE_SUFFIX = '_without_storage'
# /usr/local/lib/python3.10/dist-packages/citylearn/citylearn.py:33: DeprecationWarning: private variables, such as '_EvaluationCondition__PARTIAL_LOAD_SUFFIX', will be normal attributes in 3.11
#   __PARTIAL_LOAD_SUFFIX = '_and_partial_load'
# /usr/local/lib/python3.10/dist-packages/citylearn/citylearn.py:34: DeprecationWarning: private variables, such as '_EvaluationCondition__PV_SUFFIX', will be normal attributes in 3.11
#   __PV_SUFFIX = '_and_pv'
# name                                     Building_1  Building_2  Building_3  \
# cost_function
# annual_normalized_unserved_energy_total    0.000000    0.000000    0.000000
# annual_peak_average                             NaN         NaN         NaN
# carbon_emissions_total                     1.102550    1.121634    1.160502
# cost_total                                 1.051644    1.049357    1.099417
# daily_one_minus_load_factor_average             NaN         NaN         NaN
# daily_peak_average                              NaN         NaN         NaN
# discomfort_delta_average                   0.000000    0.000000    0.000000
# discomfort_delta_maximum                   0.000000    0.000000    0.000000
# discomfort_delta_minimum                   0.000000    0.000000    0.000000
# electricity_consumption_total              1.154070    1.201625    1.221118
# monthly_one_minus_load_factor_average           NaN         NaN         NaN
# ramping_average                                 NaN         NaN         NaN
# zero_net_energy                            1.069359    1.094072    1.096655
#
# name                                     Building_4  Building_5  District
# cost_function
# annual_normalized_unserved_energy_total    0.000000    0.000000  0.000000
# annual_peak_average                             NaN         NaN  1.095048
# carbon_emissions_total                     1.288958    1.156360  1.166001
# cost_total                                 1.238857    1.060611  1.099977
# daily_one_minus_load_factor_average             NaN         NaN  1.006957
# daily_peak_average                              NaN         NaN  1.127111
# discomfort_delta_average                   0.000000    0.000000  0.000000
# discomfort_delta_maximum                   0.000000    0.000000  0.000000
# discomfort_delta_minimum                   0.000000    0.000000  0.000000
# electricity_consumption_total              1.351710    1.251914  1.236088
# monthly_one_minus_load_factor_average           NaN         NaN  0.995422
# ramping_average                                 NaN         NaN  1.157428
# zero_net_energy                            1.109892    1.110463  1.096088

# %% [markdown]
# ## Decentralized-Independent SAC
#
# Run the following to simulate an environment controlled by decentralized-independent SAC agents for 1 training episode:

# %%
from citylearn.agents.sac import SAC as RLAgent
from citylearn.citylearn import CityLearnEnv

dataset_name = 'citylearn_challenge_2022_phase_1'
env = CityLearnEnv(dataset_name, central_agent=False, simulation_end_time_step=1000)
model = RLAgent(env)
model.learn(episodes=2, deterministic_finish=True)

# print cost functions at the end of episode
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value')
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# name                                     Building_1  Building_2  Building_3  \
# cost_function
# annual_normalized_unserved_energy_total    0.000000         0.0    0.000000
# annual_peak_average                             NaN         NaN         NaN
# carbon_emissions_total                     1.004662         1.0    1.006444
# cost_total                                 1.004593         1.0    1.005644
# daily_one_minus_load_factor_average             NaN         NaN         NaN
# daily_peak_average                              NaN         NaN         NaN
# discomfort_delta_average                   0.000000         0.0    0.000000
# discomfort_delta_maximum                   0.000000         0.0    0.000000
# discomfort_delta_minimum                   0.000000         0.0    0.000000
# electricity_consumption_total              1.004508         1.0    1.006431
# monthly_one_minus_load_factor_average           NaN         NaN         NaN
# ramping_average                                 NaN         NaN         NaN
# zero_net_energy                            1.010314         1.0    1.014362
#
# name                                     Building_4  Building_5  District
# cost_function
# annual_normalized_unserved_energy_total    0.000000    0.000000  0.000000
# annual_peak_average                             NaN         NaN  1.000224
# carbon_emissions_total                     1.000440    1.002564  1.002822
# cost_total                                 1.000505    1.002343  1.002617
# daily_one_minus_load_factor_average             NaN         NaN  0.998608
# daily_peak_average                              NaN         NaN  1.001827
# discomfort_delta_average                   0.000000    0.000000  0.000000
# discomfort_delta_maximum                   0.000000    0.000000  0.000000
# discomfort_delta_minimum                   0.000000    0.000000  0.000000
# electricity_consumption_total              1.000633    1.002679  1.002850
# monthly_one_minus_load_factor_average           NaN         NaN  0.999074
# ramping_average                                 NaN         NaN  1.000063
# zero_net_energy                            1.000529    1.002685  1.005578

# %% [markdown]
# ## Decentralized-Cooperative MARLISA
#
# Run the following to simulate an environment controlled by decentralized-cooperative MARLISA agents for 1 training episode:

# %%
from citylearn.agents.marlisa import MARLISA as RLAgent
from citylearn.citylearn import CityLearnEnv

dataset_name = 'citylearn_challenge_2022_phase_1'
env = CityLearnEnv(dataset_name, central_agent=False, simulation_end_time_step=1000)
model = RLAgent(env)
model.learn(episodes=2, deterministic_finish=True)

kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value')
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# name                                     Building_1  Building_2  Building_3  \
# cost_function
# annual_normalized_unserved_energy_total    0.000000    0.000000    0.000000
# annual_peak_average                             NaN         NaN         NaN
# carbon_emissions_total                     1.001658    1.000789    1.000947
# cost_total                                 1.002205    1.001202    1.000498
# daily_one_minus_load_factor_average             NaN         NaN         NaN
# daily_peak_average                              NaN         NaN         NaN
# discomfort_delta_average                   0.000000    0.000000    0.000000
# discomfort_delta_maximum                   0.000000    0.000000    0.000000
# discomfort_delta_minimum                   0.000000    0.000000    0.000000
# electricity_consumption_total              1.001355    1.000561    1.000642
# monthly_one_minus_load_factor_average           NaN         NaN         NaN
# ramping_average                                 NaN         NaN         NaN
# zero_net_energy                            1.002913    1.000520    1.001797
#
# name                                     Building_4  Building_5  District
# cost_function
# annual_normalized_unserved_energy_total    0.000000    0.000000  0.000000
# annual_peak_average                             NaN         NaN  1.000144
# carbon_emissions_total                     1.001103    0.999957  1.000890
# cost_total                                 1.002034    0.999780  1.001144
# daily_one_minus_load_factor_average             NaN         NaN  0.999698
# daily_peak_average                              NaN         NaN  1.000874
# discomfort_delta_average                   0.000000    0.000000  0.000000
# discomfort_delta_maximum                   0.000000    0.000000  0.000000
# discomfort_delta_minimum                   0.000000    0.000000  0.000000
# electricity_consumption_total              1.000686    1.000097  1.000668
# monthly_one_minus_load_factor_average           NaN         NaN  0.999600
# ramping_average                                 NaN         NaN  1.000677
# zero_net_energy                            1.001839    1.000932  1.001600

# %% [markdown]
# ## Stable Baselines3 Reinforcement Learning Algorithms
#
# Install the latest version of Stable Baselines3:

# %%
# !pip install shimmy==0.2.1
# !pip install stable-baselines3==2.1.0

# %% [markdown]
# Before the environment is ready for use in Stable Baselines3, it needs to be wrapped. Firstly, wrap the environment using the `NormalizedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.NormalizedObservationWrapper)) to ensure that observations served to the agent are min-max normalized between [0, 1] and cyclical observations e.g. hour, are encoded using the cosine transformation.
#
# Next, we wrap with the `StableBaselines3Wrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.StableBaselines3Wrapper)) that ensures observations, actions and rewards are served in manner that is compatible with Stable Baselines3 interface.
#
# For the following Stable Baselines3 example, the `baeda_3dem` dataset that support building temperature dynamics is used.
#
# > ⚠️ **NOTE**: `central_agent` in the `env` must be `True` when using Stable Baselines3  as it does not support multi-agents.

# %%
from stable_baselines3.sac import SAC
from citylearn.citylearn import CityLearnEnv
from citylearn.wrappers import NormalizedObservationWrapper, StableBaselines3Wrapper

dataset_name = 'baeda_3dem'
env = CityLearnEnv(dataset_name, central_agent=True, simulation_end_time_step=1000)
env = NormalizedObservationWrapper(env)
env = StableBaselines3Wrapper(env)
model = SAC('MlpPolicy', env)
model.learn(total_timesteps=env.time_steps*2)

# evaluate
observations = env.reset()

while not env.done:
    actions, _ = model.predict(observations, deterministic=True)
    observations, _, _, _ = env.step(actions)

kpis = env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value')
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/dtypes.py:35: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   from tensorflow.tsl.python.lib.core import pywrap_ml_dtypes
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# name                                       Building_1    Building_2  \
# cost_function
# annual_normalized_unserved_energy_total  3.251227e-10 -2.049072e-10
# annual_peak_average                               NaN           NaN
# cost_total                               1.037740e+00  6.016434e-01
# daily_one_minus_load_factor_average               NaN           NaN
# daily_peak_average                                NaN           NaN
# discomfort_delta_average                -3.981834e-01  7.763432e-01
# discomfort_delta_maximum                 2.259375e+00  2.658461e+00
# discomfort_delta_minimum                -3.941513e+00 -2.659611e+00
# discomfort_proportion                    2.313725e-01  4.893993e-01
# discomfort_too_cold_proportion           2.156863e-01  8.833922e-03
# discomfort_too_hot_proportion            1.568627e-02  4.805654e-01
# electricity_consumption_total            1.044388e+00  6.370223e-01
# monthly_one_minus_load_factor_average             NaN           NaN
# ramping_average                                   NaN           NaN
# zero_net_energy                          1.044388e+00  6.370223e-01
#
# name                                     Building_3    Building_4  \
# cost_function
# annual_normalized_unserved_energy_total    0.000000  2.032326e-10
# annual_peak_average                             NaN           NaN
# cost_total                                 0.761491  4.804734e-01
# daily_one_minus_load_factor_average             NaN           NaN
# daily_peak_average                              NaN           NaN
# discomfort_delta_average                   3.866776  3.287224e+00
# discomfort_delta_maximum                   6.857704  8.107384e+00
# discomfort_delta_minimum                  -3.700125 -2.782747e+00
# discomfort_proportion                      0.874543  8.301887e-01
# discomfort_too_cold_proportion             0.003654  4.354136e-03
# discomfort_too_hot_proportion              0.870889  8.258345e-01
# electricity_consumption_total              0.751090  5.356911e-01
# monthly_one_minus_load_factor_average           NaN           NaN
# ramping_average                                 NaN           NaN
# zero_net_energy                            0.751090  4.168003e-01
#
# name                                         District
# cost_function
# annual_normalized_unserved_energy_total  8.086204e-11
# annual_peak_average                      5.829849e-01
# cost_total                               7.203371e-01
# daily_one_minus_load_factor_average      9.960214e-01
# daily_peak_average                       6.309540e-01
# discomfort_delta_average                 1.883040e+00
# discomfort_delta_maximum                 4.970731e+00
# discomfort_delta_minimum                -3.270999e+00
# discomfort_proportion                    6.063759e-01
# discomfort_too_cold_proportion           5.813210e-02
# discomfort_too_hot_proportion            5.482438e-01
# electricity_consumption_total            7.420478e-01
# monthly_one_minus_load_factor_average    9.905221e-01
# ramping_average                          7.751627e-01
# zero_net_energy                          7.123251e-01
